# %%
from torch_directml import torch

# %%
t1 = torch.randint(0,255,(1,1,28,28))
print(t1)
print(255 - t1)
# Out:
# tensor([[[[119,  54,  56, 125,  26,  98, 224, 136, 132,  40, 230, 254, 218, 104,
#            172, 204, 206,  77, 126, 104,  84, 157, 214, 190,  22, 152, 205,  58],
#           [211, 221, 160, 111,  39,  36, 170, 247,  35, 163,  37, 248, 116, 249,
#            183,  51, 133, 252, 239,  51, 159, 172,  24, 204,  85, 201,  53, 204],
#           [ 15, 149, 120,  11, 107,  62, 234,  84,  38, 126,  20, 164,  62, 113,
#             34, 212,  39, 197, 222,  32,  22,  27,  41, 112,  17, 202,  35, 242],
#           [188, 188, 105, 120,  78,  30,  27, 104, 157, 128, 189,  51, 110,  87,
#            157,  28,  89, 154, 149, 145,  28, 233, 199, 143, 132, 119, 155, 137],
#           [247,  83, 237, 216,  39,  82, 224, 251,  92, 172,  80, 223, 109,  82,
#            154,  29, 254, 103, 129,  85,  29,  22,  82,  11, 191, 137, 132, 115],
#           [ 17, 253,  42, 231,  62, 242,  48,  86,  18,  70, 158, 226, 165, 140,
# ...
